# %%
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import re

# %%
URL = 'https://www.amazon.co.za/Convertible-Sofa-Bed-Apartment-High-Density/dp/B0FWKJ8FZ3/ref=sr_1_7?crid=1U4RPY2S4NCJ9&dib=eyJ2IjoiMSJ9.QtLbLXuu8pHbdNMPfc3BlQFE9rfGeDjChB2vL45l-zXCfusmT5XaChvmLQ9gyL1lwBgxNcfUWgK47-zO_gKAM8crNb4BVE3Doheen_IRfXeC-zKUfWC5CdijQ1dDuAawR79SL7jYP3kw4UhpcUf4-c5BXCYHTk7e_8pXFooIdc7Hc8x2-s87N5ocLA0yWVNnWtWAX73yTn3M-gkhRmBvE0PBnrXKoUlVA70qi_wKdsbw-m3fhxW05dJRHoxczr-n2TsJaB7bv14cHM17XCzXc9_Y9O4MnecIvCkl7AWy5u0.6vKZwn-u8z5zA_7gCA-zlN2oADn60iaYPzC3Hx1Y6t4&dib_tag=se&keywords=couch&qid=1769525774&sprefix=couch%2Caps%2C415&sr=8-7&th=1'

headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"}

page = requests.get(URL, headers=headers) 

Soup1 = BeautifulSoup(page.content, "html.parser")
Soup2 = BeautifulSoup(Soup1.prettify(), "html.parser")
title = Soup2.find(id = 'productTitle').get_text()
price = Soup2.find(id = 'apex_desktop').get_text()

print(title)
print(price)
# Out:
#            Convertible Sofa Bed – 3-Seater Modern Floor Couch, Comfy Sleeper for Living Room, Apartment or Studio, Soft Fabric & High-Density Foam (Orange)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              R 12 349,00
#
#
#
#
#
#
#                R
#
#
#                12 349
#
#                 ,
#
#
#
#                00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               All prices include VAT.

# %%
raw_text = price
clean_price = ' '.join(raw_text.replace('\xa0', ' ').split())

title = title.strip()
print(title)
print(clean_price)
# Out:
# Convertible Sofa Bed – 3-Seater Modern Floor Couch, Comfy Sleeper for Living Room, Apartment or Studio, Soft Fabric & High-Density Foam (Orange)
# R 12 349,00 R 12 349 , 00 All prices include VAT.

# %%
match = re.search(r'R\s*\d{1,3}(?:\s\d{3})*,\d{2}', clean_price)
clean_price = match.group(0) if match else None

print(clean_price)
# Out:
# R 12 349,00

# %%
print(title)
print(clean_price)
# Out:
# Convertible Sofa Bed – 3-Seater Modern Floor Couch, Comfy Sleeper for Living Room, Apartment or Studio, Soft Fabric & High-Density Foam (Orange)
# R 12 349,00

# %%
type(title)
type(clean_price)
# Out:
# str

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-01-28

# %%
import csv

header = ['title', 'price','date']
data = [title, clean_price, today]

with open('AmazonWebScrapping.csv', 'w',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\sbufr\Documents\portfolio\AmazonWebScrapping.csv')

print(df)
# Out:
#                                                title        price        date
# 0  Convertible Sofa Bed – 3-Seater Modern Floor C...  R 12 349,00  2026-01-28

# %%
with open('AmazonWebScrapping.csv', 'a+',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.co.za/Convertible-Sofa-Bed-Apartment-High-Density/dp/B0FWKJ8FZ3/ref=sr_1_7?crid=1U4RPY2S4NCJ9&dib=eyJ2IjoiMSJ9.QtLbLXuu8pHbdNMPfc3BlQFE9rfGeDjChB2vL45l-zXCfusmT5XaChvmLQ9gyL1lwBgxNcfUWgK47-zO_gKAM8crNb4BVE3Doheen_IRfXeC-zKUfWC5CdijQ1dDuAawR79SL7jYP3kw4UhpcUf4-c5BXCYHTk7e_8pXFooIdc7Hc8x2-s87N5ocLA0yWVNnWtWAX73yTn3M-gkhRmBvE0PBnrXKoUlVA70qi_wKdsbw-m3fhxW05dJRHoxczr-n2TsJaB7bv14cHM17XCzXc9_Y9O4MnecIvCkl7AWy5u0.6vKZwn-u8z5zA_7gCA-zlN2oADn60iaYPzC3Hx1Y6t4&dib_tag=se&keywords=couch&qid=1769525774&sprefix=couch%2Caps%2C415&sr=8-7&th=1'

    headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"}

    page = requests.get(URL, headers=headers) 

    Soup1 = BeautifulSoup(page.content, "html.parser")
    Soup2 = BeautifulSoup(Soup1.prettify(), "html.parser")
    title = Soup2.find(id = 'productTitle').get_text()
    price = Soup2.find(id = 'apex_desktop').get_text()
    raw_text = price
    clean_price = ' '.join(raw_text.replace('\xa0', ' ').split())
    title = title.strip()
    
    import datetime
    today = datetime.date.today()
    import csv
    header = ['title', 'price','date']
    data = [title, clean_price, today]

    with open('AmazonWebScrapping.csv', 'a+',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

    if (clean_price < 10000):
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\sbufr\Documents\portfolio\AmazonWebScrapping.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMT_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('sibusisiwekhumalo156@gmail.com','xxxxxxxxxxxxxx')
    subject = "This stylish couch is on sale! Get it while stocks last."
    body = "Sibusisiwe, This stylish couch is now on sale, for a limited time only, get it before its gone."

    msg = f"subject: {subject}\n\n{body}"

    server.sendmail(
        'sibusisiwekhumalo156@gmail.com',
        msg

    )
